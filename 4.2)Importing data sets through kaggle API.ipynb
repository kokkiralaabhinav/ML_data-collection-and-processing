# %% [markdown]
# **API - Application Programming interface**

# %%
"""
what is the use of API:
       In ML we deal with a very huge data seta and upload in google colab ans API operations 
       helps us to get the data sets quickly and use it in our collaboratory.
"""
# Installing the kaggle library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Upload your kaggle.json file**

# %%
# configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# **Importing the earthquake Data set**

# %%
#API to fetch the dataset from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
import pandas as pd
a = pd.read_csv('/content/sample_submission.csv')
print(a)
# Out:
#           seg_id  time_to_failure
# 0     seg_00030f                0
# 1     seg_0012b5                0
# 2     seg_00184e                0
# 3     seg_003339                0
# 4     seg_0042cc                0
# ...          ...              ...
# 2619  seg_ff4236                0
# 2620  seg_ff7478                0
# 2621  seg_ff79d9                0
# 2622  seg_ffbd6a                0
# 2623  seg_ffe7cc                0
#
# [2624 rows x 2 columns]

# %%
a
# Out:
#           seg_id  time_to_failure
# 0     seg_00030f                0
# 1     seg_0012b5                0
# 2     seg_00184e                0
# 3     seg_003339                0
# 4     seg_0042cc                0
# ...          ...              ...
# 2619  seg_ff4236                0
# 2620  seg_ff7478                0
# 2621  seg_ff79d9                0
# 2622  seg_ffbd6a                0
# 2623  seg_ffe7cc                0
#
# [2624 rows x 2 columns]

# %%
a.head()
# Out:
#        seg_id  time_to_failure
# 0  seg_00030f                0
# 1  seg_0012b5                0
# 2  seg_00184e                0
# 3  seg_003339                0
# 4  seg_0042cc                0
